# %% [markdown]
# <a href="https://colab.research.google.com/github/sanket012pandey/ML4SCI-DeepLense-SuperResolution-Test/blob/main/common_test_I/common_test_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Common Test I - Multi-Class Classification

# 1. Problem Statement
# Build a model to classify gravitational lensing images into 3 classes.

# 2. Imports
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt

# 3. Dataset Path
DATA_PATH = "path_to_dataset"
